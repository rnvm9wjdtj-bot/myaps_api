# %% [markdown]
# # 用友T+ API密钥工具

# %%
# 开放平台appKey
app_key = "UG69s1P1"

# 开放平台appSecret
app_secret = "F1A51CB0AD5275BF6FAA46270AF1CF37"


headers = {
    "appKey": app_key,
    "appSecret": app_secret,
    "Content-Type": "application/json",
}

# %% [markdown]
# ### 授权码换token
# 文档地址：https://open.chanjet.com/docs/file/apiFile/common/app_settled/app_settled_auth?id=32131

# %%
import requests

# 临时授权码
c = ""

response = requests.get(
    f"https://openapi.chanjet.com/auth/v2/getToken?grantType=authorization_code&redirectUri=https://baidu.com&code={c}",
    headers=headers
)

result = response.json()["result"]

access_token = result["access_token"]
refresh_token = result["refresh_token"]

# %% [markdown]
# ### 刷新token
# 文档地址：https://open.chanjet.com/docs/file/apiFile/common/base_api/oauth2?id=32130

# %%
import requests

refresh_token = "b5f8b8ad1e4f4d3ca74bd7ff4ef328e2"


response = requests.get(
    f"https://openapi.chanjet.com/auth/v2/refreshToken?grantType=refresh_token&refreshToken={refresh_token}",
    headers=headers
)

result = response.json()["result"]

access_token = result["access_token"]
refresh_token = result["refresh_token"]

print(result)
print(access_token)
print(refresh_token)
print("token已刷新，请将新token、refresh_token替换到_cache_.json文件中")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 13
#       6 response = requests.get(
#       7     f"https://openapi.chanjet.com/auth/v2/refreshToken?grantType=refresh_token&refreshToken={refresh_token}",
#       8     headers=headers
#       9 )
#      11 result = response.json()["result"]
# ---> 13 access_token = result["access_token"]
#      14 refresh_token = result["refresh_token"]
#      16 print(result)
#
# TypeError: 'NoneType' object is not subscriptable
